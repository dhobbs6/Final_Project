# %%
import pandas as pd
import os
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
# %matplotlib inline

# %%
df = pd.read_csv('./Resources/filmtv_movies - ENG.csv')
df
# Out:
#        filmtv_id                                           title  year  \
# 0              2     Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982
# 1              3                       18 anni tra una settimana  1991
# 2             17                                Ride a Wild Pony  1976
# 3             18                                           Diner  1982
# 4             20                 A che servono questi quattrini?  1942
# ...          ...                                             ...   ...
# 40298     221040                               Louis C.K.: Sorry  2021
# 40299     221041                                     Me, Natalie  1969
# 40300     221059                                         Il nero  1967
# 40301     221061  Operatsiya 'Y' i drugie priklyucheniya Shurika  1965
# 40302     221103                                    I dimma dold  1953
#
#            genre  duration        country  \
# 0      Animation        76  United States
# 1          Drama        98          Italy
# 2       Romantic        91  United States
# 3         Comedy        95  United States
# 4         Comedy        85          Italy
# ...          ...       ...            ...
# 40298     Comedy        63  United States
# 40299     Comedy       111  United States
# 40300      Drama       107          Italy
# 40301     Comedy        95   Soviet Union
# 40302   Thriller        88         Sweden
#
#                                   directors  \
# 0      David Detiege, Art Davis, Bill Perez
# 1                             Luigi Perelli
# 2                               Don Chaffey
# 3                            Barry Levinson
# 4                            Esodo Pratelli
# ...                                     ...
# 40298                            Louis C.K.
# 40299                              Fred Coe
# 40300                        Giovanni Vento
# 40301                         Leonid Gaidai
# 40302                   Lars-Eric Kjellgren
#
#                                                   actors  avg_vote  \
# 0                                                    NaN       7.7
# 1      Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5
# 2      Michael Craig, John Meillon, Eva Griffith, Gra...       5.6
# 3      Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0
# 4      Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9
# ...                                                  ...       ...
# 40298                                         Louis C.K.       6.0
# 40299  Patty Duke, James Farentino, Martin Balsam, Al...       8.0
# 40300  Joy Nwosu, Alessandra Dal Sasso, Andrea Checch...       6.0
# 40301  Aleksandr Demyanenko, Mikhail Pugovkin, Alekse...       6.0
# 40302  Eva Henning, Sonja Wigert, Hjördis Petterson, ...       6.0
#
#        critics_vote  public_vote  total_votes  humor  rhythm  effort  tension  \
# 0              8.00          7.0           22      3       3       0        0
# 1              6.00          7.0            4      0       2       0        2
# 2              6.00          5.0            9      1       2       1        0
# 3              8.00          6.0           18      2       2       0        1
# 4              5.33          7.0           15      3       1       1        0
# ...             ...          ...          ...    ...     ...     ...      ...
# 40298           NaN          6.0            1      0       0       0        0
# 40299           NaN          8.0            1      0       0       0        0
# 40300          6.00          NaN            1      0       0       0        0
# 40301          6.00          NaN            1      0       0       0        0
# 40302          6.00          NaN            1      0       3       1        3
#
#        erotism
# 0            0
# 1            0
# 2            0
# 3            2
# 4            0
# ...        ...
# 40298        0
# 40299        0
# 40300        0
# 40301        0
# 40302        0
#
# [40303 rows x 17 columns]

# %%
print(df.shape)
# Out:
# (40303, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40303 entries, 0 to 40302
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   filmtv_id     40303 non-null  int64
#  1   title         40303 non-null  object
#  2   year          40303 non-null  int64
#  3   genre         40208 non-null  object
#  4   duration      40303 non-null  int64
#  5   country       40292 non-null  object
#  6   directors     40270 non-null  object
#  7   actors        38251 non-null  object
#  8   avg_vote      40303 non-null  float64
#  9   critics_vote  35703 non-null  float64
#  10  public_vote   39829 non-null  float64
#  11  total_votes   40303 non-null  int64
#  12  humor         40303 non-null  int64
#  13  rhythm        40303 non-null  int64
#  14  effort        40303 non-null  int64
#  15  tension       40303 non-null  int64
#  16  erotism       40303 non-null  int64
# dtypes: float64(3), int64(9), object(5)
# memory usage: 5.2+ MB

# %%
df.drop_duplicates()
# Out:
#        filmtv_id                                           title  year  \
# 0              2     Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982
# 1              3                       18 anni tra una settimana  1991
# 2             17                                Ride a Wild Pony  1976
# 3             18                                           Diner  1982
# 4             20                 A che servono questi quattrini?  1942
# ...          ...                                             ...   ...
# 40298     221040                               Louis C.K.: Sorry  2021
# 40299     221041                                     Me, Natalie  1969
# 40300     221059                                         Il nero  1967
# 40301     221061  Operatsiya 'Y' i drugie priklyucheniya Shurika  1965
# 40302     221103                                    I dimma dold  1953
#
#            genre  duration        country  \
# 0      Animation        76  United States
# 1          Drama        98          Italy
# 2       Romantic        91  United States
# 3         Comedy        95  United States
# 4         Comedy        85          Italy
# ...          ...       ...            ...
# 40298     Comedy        63  United States
# 40299     Comedy       111  United States
# 40300      Drama       107          Italy
# 40301     Comedy        95   Soviet Union
# 40302   Thriller        88         Sweden
#
#                                   directors  \
# 0      David Detiege, Art Davis, Bill Perez
# 1                             Luigi Perelli
# 2                               Don Chaffey
# 3                            Barry Levinson
# 4                            Esodo Pratelli
# ...                                     ...
# 40298                            Louis C.K.
# 40299                              Fred Coe
# 40300                        Giovanni Vento
# 40301                         Leonid Gaidai
# 40302                   Lars-Eric Kjellgren
#
#                                                   actors  avg_vote  \
# 0                                                    NaN       7.7
# 1      Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5
# 2      Michael Craig, John Meillon, Eva Griffith, Gra...       5.6
# 3      Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0
# 4      Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9
# ...                                                  ...       ...
# 40298                                         Louis C.K.       6.0
# 40299  Patty Duke, James Farentino, Martin Balsam, Al...       8.0
# 40300  Joy Nwosu, Alessandra Dal Sasso, Andrea Checch...       6.0
# 40301  Aleksandr Demyanenko, Mikhail Pugovkin, Alekse...       6.0
# 40302  Eva Henning, Sonja Wigert, Hjördis Petterson, ...       6.0
#
#        critics_vote  public_vote  total_votes  humor  rhythm  effort  tension  \
# 0              8.00          7.0           22      3       3       0        0
# 1              6.00          7.0            4      0       2       0        2
# 2              6.00          5.0            9      1       2       1        0
# 3              8.00          6.0           18      2       2       0        1
# 4              5.33          7.0           15      3       1       1        0
# ...             ...          ...          ...    ...     ...     ...      ...
# 40298           NaN          6.0            1      0       0       0        0
# 40299           NaN          8.0            1      0       0       0        0
# 40300          6.00          NaN            1      0       0       0        0
# 40301          6.00          NaN            1      0       0       0        0
# 40302          6.00          NaN            1      0       3       1        3
#
#        erotism
# 0            0
# 1            0
# 2            0
# 3            2
# 4            0
# ...        ...
# 40298        0
# 40299        0
# 40300        0
# 40301        0
# 40302        0
#
# [40303 rows x 17 columns]

# %%
df = df.dropna()

# %%
df
# Out:
#        filmtv_id                            title  year     genre  duration  \
# 1              3        18 anni tra una settimana  1991     Drama        98
# 2             17                 Ride a Wild Pony  1976  Romantic        91
# 3             18                            Diner  1982    Comedy        95
# 4             20  A che servono questi quattrini?  1942    Comedy        85
# 5             21           The Uranian Conspiracy  1978       Spy       117
# ...          ...                              ...   ...       ...       ...
# 40277     219449                         Aftersun  2022  Thriller        70
# 40278     219450         Daseos beonjjae hyungchu  2022    Horror        62
# 40284     220175           Natale a tutti i costi  2022    Comedy        90
# 40286     220208                I migliori giorni  2023    Comedy       125
# 40294     220786               Filumena Marturano  2022     Drama       112
#
#                       country                             directors  \
# 1                       Italy                         Luigi Perelli
# 2               United States                           Don Chaffey
# 3               United States                        Barry Levinson
# 4                       Italy                        Esodo Pratelli
# 5      Italy, Germany, Israel  Gianfranco Baldanello, Menahem Golan
# ...                       ...                                   ...
# 40277                   Spain                          Lluís Galter
# 40278             South Korea                         Syeyoung Park
# 40284                   Italy                     Giovanni Bognetti
# 40286                   Italy       Massimiliano Bruno, Edoardo Leo
# 40294                   Italy                       Francesco Amato
#
#                                                   actors  avg_vote  \
# 1      Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5
# 2      Michael Craig, John Meillon, Eva Griffith, Gra...       5.6
# 3      Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0
# 4      Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9
# 5      Fabio Testi, Janet Agren, Assaf Dayan, Siegfri...       4.8
# ...                                                  ...       ...
# 40277  Lola Daniel, Alex Moreu, Carmela Poch, Ainoa S...       6.0
# 40278           Jihyeon Park, Hyein Moon, Seokyoung Haam       7.0
# 40284  Christian De Sica, Angela Finocchiaro, Dharma ...       4.9
# 40286  Edoardo Leo, Massimiliano Bruno, Anna Fogliett...       5.5
# 40294  Vanessa Scalera, Massimiliano Gallo, Nunzia Sc...       5.5
#
#        critics_vote  public_vote  total_votes  humor  rhythm  effort  tension  \
# 1              6.00          7.0            4      0       2       0        2
# 2              6.00          5.0            9      1       2       1        0
# 3              8.00          6.0           18      2       2       0        1
# 4              5.33          7.0           15      3       1       1        0
# 5              3.50          6.0            3      1       2       0        2
# ...             ...          ...          ...    ...     ...     ...      ...
# 40277          7.00          5.0            2      0       0       0        0
# 40278          7.00          7.0            2      0       0       0        0
# 40284          4.67          5.0           27      0       0       0        0
# 40286          6.00          5.0            4      1       2       1        1
# 40294          6.00          5.0           11      0       0       0        0
#
#        erotism
# 1            0
# 2            0
# 3            2
# 4            0
# 5            0
# ...        ...
# 40277        0
# 40278        0
# 40284        0
# 40286        0
# 40294        0
#
# [33432 rows x 17 columns]
